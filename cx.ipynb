# %% [markdown]
# <a href="https://colab.research.google.com/https://github.com/Abishekjen/cx/blob/main/cx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Mount dan install aria2c
from IPython.display import clear_output
from google.colab import drive
drive.mount('/content/drive')
# !sudo apt update
# !sudo apt install aria2
clear_output()
print("Success!")

# %%
#@title Download
LINK_FILE = "                                                                         " #@param {type:"string"}
#@markdown Path support Google Drive dan SharedDrive @ Team Drive (/content/drive/Shareddrives/OUTPUT)
PATH = "/content/drive/Shareddrives/" #@param {type:"string"}
print("Downloading.....")
# !aria2c --file-allocation=none -x16 "{LINK_FILE}" --dir="{PATH}"
print("Done!")
